# %% [markdown]
# <a href="https://colab.research.google.com/github/rcavieses/fisheries-ann-start/blob/master/clasidicacion1_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pip install tabulate

# %% [markdown]
# ![uabcs](http://uabcs.mx/dsc/mati/img/logouabcs1.png)
# <center>
# <h2> Posgrado en ciancias marinas y costeras
# <br> Departamento académico de ciencias marinas y costeras
# <br>Avances de Investigación 4°Semestre </h2>
# </center>
#
# <br>
# <br>
# ## __"Efecto de la variación de la presión de pesca ribereña sobre uno o varios recursos que interactúan de manera espacio-temporal en diferentes zonas de B.C.S; un enfoque de sistemas de inteligencia artificial”__
# ### Presenta: Ricardo Cavieses Núñez
# <br>
# 26 de noviembre de 2018
#
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## Introducción
# Sin duda la pesca artesanal es de vital importancia tanto a nivel mundial como a nivel regional, esto debido a que representa un motor económico en las comunidades asentadas en la zona costera, asegurando trabajo y seguridad alimenticia [FAO,2018](http://www.fao.org/3/I9540EN/i9540en.pdf). Es por ello que en las discusiones  preliminares  de  Río+20 se introdujo el concepto de economía azul, como un símil de la economía verde al desarrollo de la agricultura. El concepto de economía azul enfoca el aprovechamiento sustentable de los recursos marinos desarrollando las comunidades costeras de una manera integral y diversificada, fomentando actividades alternativas a la pesca que se puedan desarrollar en los litorales [Ivanova,2017](http://200.23.34.40/sociedadyambiente/index.php/sya/article/view/1768/1687)
# <br>
# Al 2012 se reportaba que  entre 30% y 40% de la producción pesquera en el mundo correspondía a pesquerías ribereñas o artesanales [Villegas,
# 2012](https://scholar.google.com/scholar?lookup=0&q=La+pesca+artesanal+como+estrategia+de+sobrevivencia:+el+caso+de+los+pescadores+en+ciudad+del+Carmen,+Campeche&hl=es&as_sdt=0,5),las cuales emplean al 90% de los pescadores del mundo [FAO,2018].  México, siendo el decimosexto país en producción por pesca, no es la excepción, ya que los datos señalan que el 40% de la pesca se realiza de manera artesanal [Ojeda,2012](http://www.redalyc.org/pdf/102/10223040006.pdf). Siendo la zona noroeste del país la más importante en términos de producción pesquera, la cual está compuesta por los estados de Sonora, Sinaloa, Baja California y Baja California Sur [SAGARPA, 2017](https://www.gob.mx/inapesca/documentos/carta-nacional-pesquera-2017).
#
# Baja California Sur es un estado con gran diversidad de ecosistemas marinos, la actividad pesquera en la entidad es en su totalidad ribereña, contando con una flota de 3596 embarcaciones y 9700 pescadores. De acuerdo a cifras preliminares, la producción pesquera en el 2017 fue de 118,868 toneladas, representando el 11% de producción nacional, alcanzando el tercer lugar en volumen de producción [SAGARPA, 2012](https://www.gob.mx/inapesca/documentos/carta-nacional-pesquera-2012).
#
# Por estas características lo diversos autores se plantean la opción de basar en el modelo la economía azul las políticas económicas del estado (teniendo el litoral más extenso de México) [Ivanova,2017](http://200.23.34.40/sociedadyambiente/index.php/sya/article/view/1768/1687).Sin embargo, la pesca es una de las actividades más complejas del sector primario y está influenciada por factores ambientales, económicos, culturales, sociales y políticos. Es por ello que para poder aplicar estas políticas, es necesario un profundo entendimiento profundo de las interacciones de estos factores al momento de tomar decisiones de manejo.
# No obstante que la actividad pesquera de ribereña artesanal no cuenta con estadísticos desagregados, con esto se da pie a que la actividad pesquera se estudie bajo la óptica de datos conglomerados por captura de especie objetivo, sin diferenciar de manera clara los datos estadísticos del recurso (artesanal e industrial) [Magadán-Revelo, et al. 2016](https://www.colpos.mx/wb_pdf/Agroproductividad/2016/AGROPRODUCTIVIDAD_V_2016.pdf#page=44).
#
# Teniendo en consideración lo anterior, se plantea la necesidad de proporcionar herramientas matemáticas que permitan esclarecer los impactos en variaciones de los factores antes mencionados, pero considerando la incertidumbre que genera la falta de datos desagregados de la actividad. Además, estas herramientas deben ponderar la complejidad de los modelos tal como lo menciona [Magnusson et al. 2013](https://onlinelibrary.wiley.com/doi/abs/10.1111/j.1467-2979.2012.00473.x)
#
# Siendo los retos de BCS  similar a la de otras regiones mundiales, se plantea como un caso de estudio ejemplar. Se pueden focalizar dos retos principales, a) el panorama actual de las pesquerías del estado se encuentran desactualizadas, y es necesario estudios que complementen los datos que proporciona la CNP  y b) existe una necesidad de desarrollar modelos que permitan simular la reacción de las pesquerías ante cambios en los factores ambientales, económicos, culturales, sociales y políticos.
#
# Es por lo anterior que el presente trabajo procura atender estos retos, proporcionando un análisis exploratorio de la base de datos de los avisos de arribo del estado. Además, se plantea que las pesquerías del estado funcionan como un sistema dinámico que reacciona ante cambios en los factores mencionados anteriormente, de este modo se propone un modelo de inteligencia artificial que entienda cada región de pesca como un nodo de información. Dicho nodo supone una cartera de productos pesqueros que se ven presionados por una demanda, los cuales podrían fluctuar su producción al percibir cambios en la vecindad de nodos.

# %% [markdown]
# ## Metodología
#
#
#
# ![alt text](https://github.com/rcavieses/fisheriesnode/blob/master/imagenes/fig4.gif?raw=true)
# <br>Figura 1. Metodología
# <br>
# ### Zona de estudio
# El estado de Baja California Sur se encuentra al Noroeste de México, tiene 2220 km de litoral, del cual
# 1400 corresponden al océano Pacífico y 820 al golfo de California, lo que resulta en 73 677 km2. La
# región cuenta con una variedad muy amplia de ecosistemas marinos, lo que contribuye a mantener
# una productividad pesquera en casi todo el año [Cortés Ortiz et al., 2006](http://www.scielo.org.mx/pdf/regsoc/v18n35/v18n35a4.pdf), [Ramírez-Rodríguez and
# Ojeda-Ruiz, 2012](https://www.repositoriodigital.ipn.mx/bitstream/123456789/12870/1/Ramirez_Rodriguez_Mauricio_2012_Marine_Policy_4023.pdf)
# ### Software
# Para el análisis de los datos y creación de los modelos se utilizó un ambiente de trabajo([link](https://drive.google.com/file/d/1DdzsESdZtkzq-dyCnobGrXfpim2PXtgL/view?usp=sharing)) de Anaconda con una versión de Python 3.6 con los paquetes: Pandas, Matplotlib,datetime,numpy,scipy,statsmodels,tabulate,seaborn,sklearn,keras-gpu,tensorflow-gpu,tensorboard. El modelo es reproducible en el archivo de colab([link](https://drive.google.com/file/d/1jJrS3bUBrZ_II5Rp2q7vacnl5aSiKOuS/view?usp=sharing))
#
# ### Análisis exploratorio
# Se usan los avisos de arribo para generar una serie histórica mensuales desde el año 2002 al 2016, de las diferentes pesquerías de pequeña escala reportadas en las oficinas de CONAPESCA, a estas se les aplicaron técnicas de estadística descriptiva,se calcularon los indices de importancia relativa a las diferentes pesquerías  [Ojeda,2012](http://www.redalyc.org/pdf/102/10223040006.pdf) posteriormente los avisos de arribo se  se agruparon por zonas siguiendo el criterio propuesto por  [Díaz-Uribe _et. al._ (2013)](https://www.researchgate.net/profile/Juan_Diaz-Uribe/publication/263504503_Regionalizacion_de_la_pesca_riberena_en_el_noroeste_de_Mexico_como_base_practica_para_su_manejo/links/0a85e53b18ebcea1d8000000/Regionalizacion-de-la-pesca-riberena-en-el-noroeste-de-Mexico-como-base-practica-para-su-manejo.pdf)el cual presenta once regiones de las cuales cuatro corresponden al estado de BCS figura 1.
#
#
# ![alt text](https://github.com/rcavieses/fisheriesnode/blob/master/imagenes/fig1.png?raw=true)
#
# Figura 2. Representación espacial de los resultados obtenidos en el análisis de agrupación [Díaz-Uribe _et. al._ (2013)](https://www.researchgate.net/profile/Juan_Diaz-Uribe/publication/263504503_Regionalizacion_de_la_pesca_riberena_en_el_noroeste_de_Mexico_como_base_practica_para_su_manejo/links/0a85e53b18ebcea1d8000000/Regionalizacion-de-la-pesca-riberena-en-el-noroeste-de-Mexico-como-base-practica-para-su-manejo.pdf).
# <br>Las oficinas se clasificaron en cuatro zonas correspondientes al estado de BCS, la cual se muestra en la tabla siguiente:
# <br>
# Tabla1. Clasificación de oficinas de pesca por zona.
# <br>
# ![alt text](https://github.com/rcavieses/fisheriesnode/blob/master/imagenes/tabla1.png?raw=true)
# <br> La base de datos de avisos de arribo se compone por 12 encabezados y 500 mil registros, se usó un algoritmo para prepara las series de tiempo, obteniendo la suma mensual de las variables de captura, valor y frecuencia de arribo de cada pesquería en cada zona.
#
# <br>  ![alt text](https://github.com/rcavieses/fisheriesnode/blob/master/imagenes/fig3.png?raw=true)<br>Figura 3. Algoritmo formato de fecha<br>
# Una vez se obtuvieron las series de tiempo, se procedió a integrar una columna indice de fechas para cada renglón, el cual corresponde a las columnas numéricas de año y mes, transformadoce a formato de fecha.
#
# Los registros se clasificación  mediante el algoritmo que se presenta en la figura 4, según la zona a la que corresponde cada oficina en la que se realizó el registro del aviso.
# <br>
# ![alt text](https://github.com/rcavieses/fisheriesnode/blob/master/imagenes/fig2.png?raw=true)
# <br>Figura 4. algoritmo de clasificación de oficinas según zona.
# <br> El a el indice de importancia relativo propuesto por [Ojeda et al. 2012](http://www.redalyc.org/pdf/102/10223040006.pdf) se calcula con la forma:
# <br><br>
# $ \displaystyle IIT_i= {{Valor_i \over Total Valor}  + {Captura_i \over Total Captura} + { Frecuencia_i \over Total Arribo}}*100  $
# <br><br>
# Además del IIR, se propone un nuevo indice de importancia relativo porcentual el cual se calcula de la siguiente forma:
# <br>
# <br>
# $ \displaystyle IIT_i= {{Valor_i \over Total Valor}  + {Captura_i \over Total Captura} + { Frecuencia_i \over Total Arribo}*100 \over 3 } $
#
# <br>Posteriormente se seleccionaron las pesquerías de mayor importancia relativa, de esta manera se crean los nodos los cuales son representados por diferentes modelos de redes neuronales profundas tales como Long-Short Term Memory (LSTM)[Hochreiter & Schmidhuber  1997](https://doi.org/10.1162/neco.1997.9.8.1735 ), covolutional neuronal network (CNN)[Waseem Rawat & Zenghui Wang 2017](https://doi.org/10.1162/neco_a_00990 ). Estos modelos siguen un entrenamiento supervisado donde los factores son indices de inflación Indice de Precios al Consumidor (IPC), Indice de Confianza del Consumidor (ICC) e Indice de Desempleo Poblacional (IDP) los cuales se descargaron de [INEGI](http://inegi.org.mx/) y las variables ambientales Temperatura Superficial del mar en grados celcius(sst), concentración de clorofila en kg/m^3 (chlor_a)y lluvia en kg/m^2 se obtuvieron de [GIOVANNI](http://giovanni.gsfc.nasa.gov). La variable objetivo de cada modelo es la captura de las pesquerías. Estos modelos fueron optimizados mediante algoritmos de búsquedas iterativas de los hiperparámetros y de los parámetros. Para validar los modelos se usa un conjunto de datos testigo el cual fue separado previamente del conjunto de entrenamiento y se calcula el coeficiente de correlación R² de Spearman y la suma cuadrática del error medio de  las simulaciones versus el conjunto testigo.

# %% [markdown]
# ## Desarrollo del codigo
# ### Preparación de las series de tiempo de pesquerías

# %%
##Se cargan los paquetes
from pandas import DataFrame
from pandas import concat
from pandas import read_csv
from datetime import datetime
from matplotlib import pyplot
import pandas as pd
import numpy as np
from scipy import stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy.stats import shapiro
from tabulate import tabulate
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.layers.advanced_activations import LeakyReLU
from keras.layers import  MaxPooling1D, Flatten
from keras.callbacks import TensorBoard
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Using TensorFlow backend.

# %%
#importacion de los datos
dataset = read_csv('gdrive/My Drive/ColabNotebooks/Tesis_notebook/BDGENERAL.csv', header=0, index_col=0)
#obtener los encabezados
Encabezados=dataset.columns.values.tolist()

#obtener la lista de las oficinas que se tienen dentro de la base de datos
Oficinas=dataset.Oficina.values.tolist()#  extrae la columna de oficinas como una lista
a=pd.Series(Oficinas, dtype="category") #combierte de lista a serie
acat=a.cat.categories #extrae las categorías de la serie
oficinas=pd.Series.tolist(acat) #convierte las categorias en una lista
frecOficina=pd.value_counts(dataset['Oficina'])

#Se obtiene la lista de las pesquerías 
Pesqueria=dataset.Pesqueria.values.tolist()
c=pd.Series(Pesqueria,dtype="category")
acatp=c.cat.categories
pesquerias=pd.Series.tolist(acatp)
frecPesqueria=pd.value_counts(dataset['Pesqueria'])

#Se obtiene la lista de los años
Anos=dataset.Ano.values.tolist()
c=pd.Series(Anos,dtype="category")
acaty=c.cat.categories
años=pd.Series.tolist(acaty)
frecAnos=pd.value_counts(dataset['Ano'])

#Se obtiene la lista de los meses
Mes=dataset.Mes.values.tolist()
c=pd.Series(Mes,dtype="category")
acatm=c.cat.categories
meses=pd.Series.tolist(acatm)
frecMes=pd.value_counts(dataset['Mes'])

#Se crea una lista con los valores filtrados y sumados de las capturas para cada oficina, pesquería, mes y año.
df=['Oficina','Pesq','año','mes','peso','valor','frecuencia'] #se definen los encabezados del arreglo
df1=pd.DataFrame(columns=df)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
#  Se preparan las series de tiempo, con el algoritmo de la figura 2.

# %%
contador=0
for i in range(0,len(oficinas)):
    V=dataset.Oficina==acat[i]
    for j in range(0,len(pesquerias)):
        VV=dataset.Pesqueria==acatp[j]
        for k in range(0,len(años)):
            VVV=dataset.Ano==acaty[k]
            for l in range(0,len(meses)):
                VVVV=dataset.Mes==acatm[l]#genera lista donde ambos son verdaderos
                M=V & VV & VVV & VVVV 
                B=sum(dataset.Peso[M==True])#muestra los registros que cumplen la condición anterior
                C=sum(dataset.Valor[M==True])#muestra la suma del valor para el año en esa oficina
                fr=dataset.Peso[M==True].size
                df1.loc[contador]=[acat[i],acatp[j],acaty[k],acatm[l],B,C,fr]
                contador=contador+1

# %% [markdown]
# Una vez se tienen las series de tiempo en un DataFrame, se le debe agregar la columna de indice en formato de fechas.

# %%
#Se crea una columna con las fechas en formato yyyy-mm-dd y se une al arreglo anterior
dt=['DATE']
dt=pd.DataFrame(columns=dt)
contador=0
for x in range(0,len(df1)):
    z=df1.values[x,2:3]#se extrae la columna de año
    zZ=df1.values[x,3:4]#se extrae la columna de mes
    zzz=datetime(z,zZ,1)# se convierte a formato de fecha
    dt.loc[contador]=[zzz.strftime("%Y-%m-%d")]#se agrega al dataframe
    contador=contador+1

df1 = df1.assign(Date=dt.values)#el data frame creado se une como columna al datafraem que contiene todos los datos

# %% [markdown]
# Ahora se aplica el algoritmo de clasificación de las oficinas para cada zona, como en la figura 3.

# %%
df=['Zona']
ZNc=[]
ZN=pd.DataFrame(ZNc,columns=df)

i=0

for i in range(0,len(df1)):
                if df1.Oficina[i]=='LORETO' or df1.Oficina[i]== 'LA PAZ' or df1.Oficina[i]== 'SANTA ROSALIA' or df1.Oficina[i]=='LOS CABOS':
                    nd1='zn1'
                    ZN.loc[i]=[nd1]
                    i=i+1
                elif  df1.Oficina[i]=='PUERTO ADOLFO LOPEZ MATEOS' or df1.Oficina[i]=='CD. CONSTITUCION'or df1.Oficina[i]=='SAN CARLOS':
                    nd1='zn2'
                    ZN.loc[i]=[nd1]
                    i=i+1
                elif df1.Oficina[i]=='BAHIA TORTUGAS' or df1.Oficina[i]=='BAHIA ASUNCION'or df1.Oficina[i]=='PUNTA ABREOJOS' or df1.Oficina[i]=='ISLA DE CEDROS':
                    nd1='zn3'
                    ZN.loc[i]=[nd1]
                    i=i+1
                elif df1.Oficina[i]=='GUERRERO NEGRO':
                    nd1='zn4'
                    ZN.loc[i]=[nd1]
                    i=i+1
                else:
                    nd1='NaN'
                    ZN.loc[i]=[nd1]
                    i=i+1

# %% [markdown]
# La nueva tabla de datos se escribio en un archivo de formato CSV, este archivo se utilizará para el análisis de las pesquerías por zona. Posteriormente se usará para crear las series de tiempo con las que se entrenarán los algoritmos de IA.

# %%
(len(ZN)/len(dataset))*100 #porcentaje de resumen de la bd 
df1 = df1.assign(Zona=ZN.values)
df1.to_csv('bdmensualclasificada.csv')

# %% [markdown]
# Para generar las series de tiempo de cada pesqueríaes necesario clasificar la base de datos por pesqueria y ordenar por fehca.

# %%
# se lee el archivo generado anteriormente
df = read_csv('bdmensualclasificada.csv', header=0, index_col=0)
Encabezados=df.columns.values.tolist()

# %%
#Se elimina la pesquería de calamar para ser estudiada por separado debído al sesgo que causa
Calamar=df[df.Pesq=='CALAMAR']
df=df[df.Pesq!='CALAMAR']
#Creamos una tabla nueva, donde se agrupen los datos por año y pesquería, presentando los valores acumulados.
tabla1=df.groupby(['año','Pesq'],as_index=False).sum().pivot('año','Pesq').fillna(0)
Pesquerias=df.Pesq.values.tolist()
c=pd.Series(Pesquerias,dtype="category")
labelp=c.cat.categories

# %% [markdown]
# Se hace el calculo del IIR con la ecuación antes propuesta

# %%
perValor=tabla1.valor/tabla1.valor.sum()
perPeso=tabla1.peso/tabla1.peso.sum()
perFrec=tabla1.frecuencia/tabla1.frecuencia.sum()
IIR= (perValor+perPeso+perFrec)*100

# %% [markdown]
# ## Resultados del analisis exploratorio de las series de tiempo de las pesquerías

# %% [markdown]
# ### Series de tiempo anuales de las diferentes pesquerías del estado
# Es importante destacar que no se ha descontado la variación del valor del dinero en el tiempo.

# %%
fig=pyplot.figure(1,figsize=(15,15))
pyplot.subplot(221)
pyplot.title('a)')
pyplot.plot(tabla1.valor)
pyplot.legend(labelp,bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
pyplot.ylabel('pesos',size=20)
pyplot.subplot(222)
pyplot.title('b)')
pyplot.plot(tabla1.peso)
pyplot.legend(labelp,bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
pyplot.ylabel('kg',size=20)
pyplot.subplot(223)
pyplot.title('c)')
pyplot.plot(tabla1.frecuencia)
pyplot.legend(labelp,bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
pyplot.ylabel('frecuencia',size=20)
pyplot.subplot(224)
pyplot.title('d)')
pyplot.plot(IIR)
pyplot.legend(labelp,bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
pyplot.ylabel('IIR',size=20)
pyplot.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=1, hspace=0.15,
                    wspace=0.55)

# %% [markdown]
# Figura 5. Series de tiempo anuales de las pesquerías de BCS

# %%
fig=pyplot.figure(1,figsize=(15,5))
pyplot.subplot(231)
pyplot.title('a)')
Cal=Calamar.groupby(['año']).sum()
pyplot.plot(Cal.peso)
pyplot.legend('Calamar',bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
pyplot.ylabel('Kg',size=20)
pyplot.subplot(232)
pyplot.title('b)')
Cal=Calamar.groupby(['año']).sum()
pyplot.plot(Cal.valor)
pyplot.legend('Calamar',bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
pyplot.ylabel('Pesos',size=20)
pyplot.subplot(233)
pyplot.title('c)')
Cal=Calamar.groupby(['año']).sum()
pyplot.plot(Cal.frecuencia)
pyplot.legend('Calamar',bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
pyplot.ylabel('Frecuencia',size=20)
pyplot.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=1, hspace=0.15,
                    wspace=0.55)

# %% [markdown]
# Figura 6. Serie de tiempo de la pesquería del calamar'

# %% [markdown]
#  En terminos generales los datos anuales del estado podemos observar que el calamar se dejó de arribar desde el año 2009, por tener grandes volúmenes de captura esta pesquería debe ser separada del análisis de las pesquerías del estado, de lo contrario generaría un segso significativo y no se podría apreciar la importancia actual de las otras pesquerías que siguen en funcionamiento hasta la actualidad.

# %%
Captura=tabla1.peso.sum()
Value=tabla1.valor.sum()
Frecuencia=tabla1.frecuencia.sum()
IIRt=IIR.sum()

# %% [markdown]
#  De la tabla siguiente podemos observar que la principal pesquería del estado es la escama (45% ), recurso que ha tomado especial importancia desde el año 2014, en el cual paso a liderar el ingreso económico, a partir del año 2008 es el recurso que más volumen ingresa, finalmente desde el 2002 es el que registra una mayor frecuencia de avisos de arribo. Es interesante observa que del año 2008 al 2012 el Abulón tuvo  un repunte en su IIR, eso debido a que el valor económico de la pesquería de camarón y almeja cayeron drásticamente.

# %%
# calculo del indice de importancia relativa porcentual y preparación de resultados
IIRTotal= ((Value/Value.sum()+Captura/Captura.sum()+Frecuencia/Frecuencia.sum())*100)/3
tab=['Pesquería','IIP','Captura','Valor','Frecuencia']
Tab=pd.DataFrame(columns=tab) 
val=IIRTotal.values
val=val.reshape(14,1)
etiquetas=labelp.values
Tab.Pesquería=etiquetas
Tab.IIP=val
Tab.Valor=Value.values
Tab.Captura=Captura.values
Tab.Frecuencia=Frecuencia.values
print(chr(27)+"[1m"+"Tabla 2. Indice de importancia porcentual") 
print(chr(27)+"[0m"+tabulate(Tab,showindex=False,headers=tab,tablefmt='fancy_grid'))
print('*Captura en Kg')
print('**Valor en pesos mexicanos')
# Out:
# Tabla 2. Indice de importancia porcentual
# ╒══════════════════╤═══════════╤══════════════════╤═════════════╤══════════════╕
# │ Pesquería        │       IIP │          Captura │       Valor │   Frecuencia │
# ╞══════════════════╪═══════════╪══════════════════╪═════════════╪══════════════╡
# │ ABULON           │  2.58093  │      4.61009e+06 │ 5.83475e+08 │         5017 │
# ├──────────────────┼───────────┼──────────────────┼─────────────┼──────────────┤
# │ ALGAS            │  0.839764 │      7.44406e+06 │ 5.70087e+07 │         2491 │
# ├──────────────────┼───────────┼──────────────────┼─────────────┼──────────────┤
# │ ALMEJAS          │ 17.3219   │      1.68658e+08 │ 1.53198e+09 │        22567 │
# ├──────────────────┼───────────┼──────────────────┼─────────────┼──────────────┤
# │ CALLO DE HACHA   │  1.08201  │      2.27197e+06 │ 1.72092e+08 │         5054 │
# ├──────────────────┼───────────┼──────────────────┼─────────────┼──────────────┤
# ...

# %% [markdown]
# ### Resultados del análisis de los datos por zonas de captura

# %%
#agrupamos los datos en una tabla por pesquería y zona, se suman sus valores y se etiquetan.
tabla2=df.groupby(['Pesq','Zona'],as_index=False).sum().pivot('Pesq','Zona')
zonas=df.Zona.values.tolist()
c=pd.Series(zonas,dtype="category")
label=c.cat.categories

# %% [markdown]
# En la figura de boxplot no se muestran los datos anómalos, de esta se puede observar que la zona 2 tiene la mayor variación en cuanto a capturas, la zona 1 y 3 son similares, la zona 4 es la que presenta menores capturas y menor dispersión de los datos.

# %%
tabla3=df.groupby(['Date','Zona'],as_index=False).sum()
tabla3.boxplot('peso', by='Zona',showfliers=False, figsize=(12, 8))

# %% [markdown]
# Figura 7.Boxplot de las capturas por zona

# %% [markdown]
# La figura siguiente, en el gráfico de pay, se puede observar que la zona dos presenta la mayor proporción de captura en relación a las otras tres zonas, en la primera y tercer zona la principal captura es de la pesquería de escama 8.04e+05kg, para la zona 2 la principal captura corresponde a almejas con 1.5e+08kg, tal como se muestra en la grafica de barras.

# %%
pyplot.figure(figsize=(10,10))

ac1=pyplot.subplot(221)
tabla2.peso.sum().plot.pie(y='kg', autopct='%1.1f%%')
pyplot.title('Porcentaje de captura para cada zona')

ac2=pyplot.subplot(222)
tabla2.peso.plot.barh(rot=0, ax=ac2, stacked=True, width=1)
pyplot.xlabel('Kg',size=20)
pyplot.grid()
ac3=pyplot.subplot(223)
tabla2.valor.plot.barh(rot=0,ax=ac3,stacked=True, width=1)
pyplot.xlabel('Pesos',size=20)
pyplot.grid()
ac4=pyplot.subplot(224)
tabla2.frecuencia.plot.barh(rot=0,ax=ac4, stacked=True, width=1)
pyplot.xlabel('frecuencia',size=20)
pyplot.xticks(rotation=45)
pyplot.grid()
pyplot.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=1, hspace=0.50,
                    wspace=0.55)

# %% [markdown]
# Figura 8. Análisis descriptivo por zona

# %% [markdown]
# En comparación con las zonas 1,2 y 4, la zona 3 tiene su mayor ingreso por la pesquería de langosta con un acumulado de 2.2e+09 pesos. El análisis de dispersión de datos, como se muestra en la siguiente figura observamos la distribución de los datos confrontado cada columna en la cual existe en la mayoría dos conjuntos bien definidos de datos, lo cual corresponde al grupo de datos de la pesquería de escama y el segundo pertenece al conjunto de datos de las demás pesquerías.

# %%
# Se crean las series de tiempo que entrarán como input para los modelos de IA. 
tabla4=df.groupby(['Date','Zona','Pesq'],as_index=False).sum()#ordenamos los datos clasificados por fecha, zona y pesquería
Z1=tabla4.Zona=='zn1'#usamos un vector boleano para clasificarlos por zona
Z2=tabla4.Zona=='zn2'
Z3=tabla4.Zona=='zn3'
Z4=tabla4.Zona=='zn4'
ZN1=tabla4[Z1==True]
ZN2=tabla4[Z2==True]
ZN3=tabla4[Z3==True]
ZN4=tabla4[Z4==True]
#se eliminan las columnas que no se utilizan y agrupamos nuevamente los datos
ZN1=ZN1.drop(columns=['Zona','año','mes'])
ZN1t=ZN1.groupby(['Date','Pesq'],as_index=False).sum().fillna(0).pivot('Date','Pesq').fillna(0)
ZN2=ZN2.drop(columns=['Zona','año','mes'])
ZN2t=ZN2.groupby(['Date','Pesq'],as_index=False).sum().fillna(0).pivot('Date','Pesq').fillna(0)
ZN3=ZN3.drop(columns=['Zona','año','mes'])
ZN3t=ZN3.groupby(['Date','Pesq'],as_index=False).sum().fillna(0).pivot('Date','Pesq').fillna(0)
ZN4=ZN4.drop(columns=['Zona','año','mes'])
ZN4t=ZN4.groupby(['Date','Pesq'],as_index=False).sum().fillna(0).pivot('Date','Pesq').fillna(0)
#creamos otra  tabla para analizar las zonas de manera conjunta
ST=df.drop(columns=['Oficina','año'])
ST=ST.groupby(['Date','Zona','Pesq'],as_index=False).sum().fillna(0)
sns.pairplot(ST)

# %% [markdown]
# Figura 9. Análisis de distribución por campo de la BD

# %% [markdown]
# ### Zona 1
# <br>Se realiza un análisis de correlación entre las pesquerías

# %%
#Se agrupan los datos en una nueva tabla
C=ST.Zona=='zn1'
ZN1=ST[C==True]
X=df.Zona=='zn1'
tZN1=ZN1.groupby(['Date','Pesq'],as_index=False).sum().pivot('Date','Pesq').fillna(0)
ta1=ST.groupby(['Pesq','mes'],as_index=False).sum().pivot('Pesq','mes').fillna(0)

# %%
fig=pyplot.figure(1,figsize=(25,20))
pyplot.subplot(221)
ax1=sns.heatmap(ZN1t.peso.corr(),annot=True,vmin=-1,vmax=1,cmap="Greys")
pyplot.title('Correlación de volumen de captura')
# Out:
# Text(0.5,1,'Correlación de volumen de captura')

# %% [markdown]
# Figura 10. correlación entre pesquerías de la zona1

# %% [markdown]
# Este análisis de correlación revela que no existe una relación lineal (grafica anterior) significativa entre las pesquerías de la zona uno, máxima correlación R=0,58. En la zona 1 se pesca escama todo el año (figura siguiente), siendo los meses de junio ,julio y octubre los que presentan las mayores capturas. Siendo las principales pesquerías la escama, camarón, almejas y tiburones.

# %%
fig=pyplot.figure(1,figsize=(30,15))
pyplot.subplot(221)
ax1=sns.heatmap(ZN1t.peso.corr(),vmin=-1,vmax=1,cmap="Greys")
pyplot.title('Correlación de volumen de captura')
pyplot.subplot(222)
ax2=sns.heatmap(ZN1t.valor.corr(),vmin=-1,vmax=1,cmap="Greys")
pyplot.title('Correlación de valor de captura')
pyplot.subplot(223)
ax3=sns.heatmap(ZN1t.frecuencia.corr(),vmin=-1,vmax=1,cmap="Greys")
pyplot.title('Correlación de frecuencia de arribo de captura')
pyplot.subplot(224)
ax3=sns.heatmap(ta1.peso, cmap="Greys")
pyplot.title('Meses de captura')
pyplot.subplots_adjust(top=0.82, bottom=0.10, left=0.01, right=0.6, hspace=0.40,
                    wspace=0.5)

# %% [markdown]
# Figura 11. Análisis de correlación entre variables de las pesquerías y temporada de pesca

# %% [markdown]
# ### Zona 2
#
# Este análisis de correlación revela que no existe una relación lineal (grafica anterior) significativa entre las pesquerías de la zona uno, máxima correlación R=0,58. En la zona 1 se pesca escama todo el año (figura siguiente), siendo los meses de junio ,julio y octubre los que presentan las mayores capturas. Siendo las principales pesquerías la escama, camarón, almejas y tiburones.

# %%
C2=ST.Zona=='zn2'
ZN2=ST[C2==True]
X=df.Zona=='zn2'
XX=df.Pesq!='CALAMAR'
L=X&XX
tt=df[L==True]
tZN2=ZN2.groupby(['Date','Pesq'],as_index=False).sum().pivot('Date','Pesq').fillna(0)
ta2=tt.groupby(['Pesq','mes'],as_index=False).sum().pivot('Pesq','mes').fillna(0)

fig=pyplot.figure(1,figsize=(15,15))
pyplot.subplot(221)
ax1=sns.heatmap(tZN2.peso.corr(),vmin=-1,vmax=1,cmap="Greys")
pyplot.title('Correlación de volumen de captura')
pyplot.subplot(222)
ax2=sns.heatmap(tZN2.valor.corr(),vmin=-1,vmax=1,cmap="Greys")
pyplot.title('Correlación de valor de captura')
pyplot.subplot(223)
ax3=sns.heatmap(tZN2.frecuencia.corr(),vmin=-1,vmax=1,cmap="Greys")
pyplot.title('Correlación de frecuencia de arribo de captura')
pyplot.subplot(224)
ax3=sns.heatmap(ta2.peso, cmap="Greys")
pyplot.title('Meses de captura')
pyplot.subplots_adjust(top=0.82, bottom=0.10, left=0.1, right=1, hspace=0.55,
                    wspace=0.65)

# %% [markdown]
# Figura 12. Análisis de correlación entre variables de las pesquerías y temporada de pesca

# %% [markdown]
# ### Zona 3
# Al igual que en las otras zonas no se encontró una correlación lineal, se puede observar que hay una mayor diversidad de pesquerías, donde la escama se pesca todo el año pero principalmente en los meses de abril a septiembre, también es importante señalar que se tiene una producción de algas en los meses de abril a octubre,pepino de mar se captura en los meses de junio y julio, caracol en los meses de marzo a octubre, abulón se captura de los meses febrero a agosto y finalmente langosta de los meses de septiembre a febrero figura(d).

# %%
C3=ST.Zona=='zn3'
ZN3=ST[C3==True]
X=df.Zona=='zn3'
XX=df.Pesq!='CALAMAR'
L=X&XX
tt=df[L==True]
tZN3=ZN3.groupby(['Date','Pesq'],as_index=False).sum().pivot('Date','Pesq').fillna(0)
ta3=tt.groupby(['Pesq','mes'],as_index=False).sum().pivot('Pesq','mes').fillna(0)

fig=pyplot.figure(1,figsize=(15,15))
pyplot.subplot(221)
ax1=sns.heatmap(tZN3.peso.corr(),vmin=-1,vmax=1,cmap="Greys")
pyplot.title('Correlación de volumen de captura')
pyplot.subplot(222)
ax2=sns.heatmap(tZN3.valor.corr(),vmin=-1,vmax=1,cmap="Greys")
pyplot.title('Correlación de valor de captura')
pyplot.subplot(223)
ax3=sns.heatmap(tZN3.frecuencia.corr(),vmin=-1,vmax=1,cmap="Greys")
pyplot.title('Correlación de frecuencia de arribo de captura')
pyplot.subplot(224)
ax3=sns.heatmap(ta3.peso, cmap="Greys")
pyplot.title('Meses de captura')
pyplot.subplots_adjust(top=0.82, bottom=0.10, left=0.15, right=1, hspace=0.55,
                    wspace=0.65)

# %% [markdown]
# Figura 13. Análisis de correlación entre variables de las pesquerías y temporada de pesca

# %% [markdown]
# ### zona 4
# No se encotro correlación lineal, en esta zona se pesca almejas todo el año siendo los principales meses junio,julio y octubre. La lngosta se pesca en los mesesde septiembre a noviembre. La escama presenta capturas todo el año y los tiburones y rayas se pescan en los meses de agosto a octubre.

# %%
C4=ST.Zona=='zn4'
ZN4=ST[C==True]
X=df.Zona=='zn4'
XX=df.Pesq!='CALAMAR'
L=X&XX
tt=df[L==True]
tZN4=ZN4.groupby(['Date','Pesq'],as_index=False).sum().pivot('Date','Pesq').fillna(0)
ta4=tt.groupby(['Pesq','mes'],as_index=False).sum().pivot('Pesq','mes').fillna(0)

fig=pyplot.figure(1,figsize=(15,15))
pyplot.subplot(221)
ax1=sns.heatmap(tZN4.peso.corr(),vmin=-1,vmax=1,cmap="Greys")
pyplot.title('Correlación de volumen de captura')
pyplot.subplot(222)
ax2=sns.heatmap(tZN4.valor.corr(),vmin=-1,vmax=1,cmap="Greys")
pyplot.title('Correlación de valor de captura')
pyplot.subplot(223)
ax3=sns.heatmap(tZN4.frecuencia.corr(),vmin=-1,vmax=1,cmap="Greys")
pyplot.title('Correlación de frecuencia de arribo de captura')
pyplot.subplot(224)
ax3=sns.heatmap(ta4.peso, cmap="Greys")
pyplot.title('Meses de captura')
pyplot.subplots_adjust(top=0.82, bottom=0.10, left=0.15, right=1, hspace=0.55,
                    wspace=0.65)

# %% [markdown]
# Figura 14. Análisis de correlación entre variables de las pesquerías y temporada de pesca

# %% [markdown]
# Finalmente se realizó un análisis de correlación entre las diferentes zonas, donde podemos observar que las que corresponden al pacífico tienen una correlación elevada (R=0.99), no así las demás.

# %%
ax3=sns.heatmap(tabla2.peso.corr(),annot=True,vmin=-1,vmax=1,cmap="Greys")

# %% [markdown]
# Figura 15. Análisis de correlación entre variables de las pesquerías entre zonas

# %% [markdown]
# Una ves hecha el análisis exploratorio de los datos, se procedio a incluir  las variables económicas las cuales se descargaron de [INEGI](http://inegi.org.mx/) y las variables ambientales que se obtuvieron de [GIOVANNI](http://giovanni.gsfc.nasa.gov), las series de tiempo corresponden del año 2002 al 2016.

# %%
#cargar las variables
economicas = read_csv('gdrive/My Drive/ColabNotebooks/Tesis_notebook/economicas.csv', header=0, index_col=0)
ambientales = read_csv('gdrive/My Drive/ColabNotebooks/Tesis_notebook/ambientales.csv', header=0,index_col=0)

# %%
fig=pyplot.figure(1,figsize=(15,15))
xti=list(range(2000,2018,2))
pyplot.subplot(321)
ax=economicas.IPC.plot()
ax.set_xticklabels(xti,rotation=90)
pyplot.title('IPC')
pyplot.xlabel('Año')

pyplot.subplot(322)
ax2=economicas.ICC.plot()
ax2.set_xticklabels(xti,rotation=90)
pyplot.title('ICC')
pyplot.xlabel('Año')

pyplot.subplot(323)
ax3=economicas.IPD.plot()
ax3.set_xticklabels(xti,rotation=90)
pyplot.title('IPD')
pyplot.xlabel('Año')

pyplot.subplot(324)
ax4=ambientales.sst.plot()
ax4.set_xticklabels(xti,rotation=90)
pyplot.title('TSM')
pyplot.xlabel('Año')

pyplot.subplot(325)
ax5=ambientales.chlor_a.plot()
ax5.set_xticklabels(xti,rotation=90)
pyplot.title('CLA')
pyplot.xlabel('Año')

pyplot.subplot(326)
ax4=ambientales.Rain.plot()
ax4.set_xticklabels(xti,rotation=90)
pyplot.title('LLUVIA')
pyplot.xlabel('Año')
pyplot.subplots_adjust(top=0.82, bottom=0.10, left=0.15, right=1, hspace=0.55,
                    wspace=0.65)

# %% [markdown]
# Figura 16. Series de tiempo entre variables exógenas

# %% [markdown]
# Se corta la serie de tiempo correspondiente a las pesquerías con la finalidad de unirlas posteriormente a las series de tiempo de las variables exógenas.

# %%
row_to_drop=range(0,30,1)#rango de corte
ZN1t=ZN1t.drop(ZN1t.index[[row_to_drop]])
ZN2t=ZN2t.drop(ZN2t.index[[row_to_drop]])
ZN3t=ZN3t.drop(ZN3t.index[[row_to_drop]])
ZN4t=ZN4t.drop(ZN4t.index[[row_to_drop]])
#se escriben archivos csv para cada zona, con los cuales se alimentaran a los modelos
izn1= pd.concat([ZN1t.peso, economicas, ambientales], axis=1).to_csv('izn1.csv')
izn2= pd.concat([ZN2t.peso, economicas, ambientales], axis=1).to_csv('izn2.csv')
izn3= pd.concat([ZN3t.peso, economicas, ambientales], axis=1).to_csv('izn3.csv')
izn4= pd.concat([ZN4t.peso, economicas, ambientales], axis=1).to_csv('izn4.csv')

# %% [markdown]
# ## Preparación de modelos de IA
#
#  Se carga el archivo creado en el capitulo anterior, donde además se le agregaron las columnas de las variables exógenas. Posteriormente se aplica un "reframe" para recorrer las variables y crear una matriz que se utilizo para crear los conjuntos de entrenamiento y test. Los datos se estandarizan de 0 a 1.

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
        dropnan: Boolean whether or not to drop rows with NaN values.
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
    names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %% [markdown]
# ### modelo nodo 1

# %%
#importacion de los datos
dataset = read_csv('izn1.csv', header=0, index_col=0)
# ensure all data is float
dataset=dataset.convert_objects(convert_numeric=True)
values = dataset.values
encoder = LabelEncoder()
values[:,1] = encoder.fit_transform(values[:,1])
values = values.astype('float64')
values= pd.DataFrame(values).fillna(0)
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
reframed = series_to_supervised(scaled, 1, 1)
reframed.drop(reframed.columns[[15,16,17,18,19,20]], axis=1, inplace=True)
# se dividen los datos en conjunto de entrenamiento y en conjunto de test
values = reframed.values
n_train_hours = len(reframed)-34#aquí divido asígno el numero de datos para test
train = values[:n_train_hours, :]#aquí separo los datos para el entrenamiento
test = values[n_train_hours:, :]#los datos para el test
print(values.shape,train.shape,test.shape)
# Out:
# (173, 34) (139, 34) (34, 34)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# # se dividen los datos en conjunto de input y en conjunto de output
train_X = train[:, :-14]
train_y = train[:,:14 ]#aquí seleccionas el vector correspondiente a pronóstico
test_X=  test[:, :-14]
test_y = test[:, :14]#idem
# reshape input a 3D [muestra, timesteps, características]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))


print(test_X.shape)
# Out:
# (34, 1, 20)

# %%
# diseño del modelo
model = Sequential()
model.add(LSTM(150,return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dropout(0.2))
model.add(Activation('linear'))
model.add(LeakyReLU(alpha=0.2))
model.add(MaxPooling1D(pool_size=2,padding='same'))
model.add(Dense(14))
model.add(LSTM(150,return_sequences=True,input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dropout(0.2))
model.add(Activation('relu'))
model.add(LSTM(50,input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dropout(0.6))
model.add(Activation('linear'))
model.add(Dense(14))
model.compile(loss='mae', optimizer='adamax')
tensorboard = TensorBoard(log_dir='./run_test', histogram_freq=1,
                          write_graph=True, write_images=False)
tensorboard.set_model(model) 

history = model.fit(train_X, train_y, epochs=50, batch_size=5,validation_data=(test_X, test_y),verbose=1,shuffle=False,callbacks=[tensorboard])
# Out:
# Train on 139 samples, validate on 34 samples
# Epoch 1/50
# 139/139 [==============================] - 2s 15ms/step - loss: 0.0685 - val_loss: 0.1637
# Epoch 2/50
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0704 - val_loss: 0.1675
# Epoch 3/50
# 139/139 [==============================] - 0s 3ms/step - loss: 0.0678 - val_loss: 0.1656
# Epoch 4/50
# 139/139 [==============================] - 0s 2ms/step - loss: 0.0690 - val_loss: 0.1677
# Epoch 5/50
# 139/139 [==============================] - 0s 2ms/step - loss: 0.0668 - val_loss: 0.1638
# Epoch 6/50
# 139/139 [==============================] - 0s 2ms/step - loss: 0.0676 - val_loss: 0.1626
# Epoch 7/50
# 139/139 [==============================] - 0s 2ms/step - loss: 0.0639 - val_loss: 0.1514
# Epoch 8/50
# 139/139 [==============================] - 0s 2ms/step - loss: 0.0618 - val_loss: 0.1409
# Epoch 9/50
# 139/139 [==============================] - 0s 2ms/step - loss: 0.0590 - val_loss: 0.1354
# Epoch 10/50
# ...

# %% [markdown]
# tabla 3. Resumen de restructura del modelo LSTM nodo 1

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_1 (LSTM)                (None, 1, 150)            102600
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 150)            0
# _________________________________________________________________
# activation_1 (Activation)    (None, 1, 150)            0
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 1, 150)            0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 1, 150)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1, 14)             2114
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1, 150)            99000
# ...

# %%
pyplot.figure(figsize=(10,10))
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %% [markdown]
# Figura 17. historial de rendimiento del entrenamiento y test

# %%
test_X.shape
# Out:
# (34, 1, 20)

# %%
#Se realiza el pronpóstico
yhat = model.predict(test_X)
test_X1=test_X.reshape((test_X.shape[0], test_X.shape[2]))
print(yhat.shape,test_X1.shape)
# invert scaling for forecast
inv_yhat = np.concatenate((yhat, test_X1[:, 14:]), axis=1)
inv_yhat2 = scaler.inverse_transform(inv_yhat)
inv_yhat3 = inv_yhat2[:,]
# invert scaling for actual
test_y2 = test_y.reshape((len(test_y), 14))
inv_y = np.concatenate((test_y2, test_X1[:, 14:]), axis=1)
inv_y2 = scaler.inverse_transform(inv_y)
inv_y3 = inv_y2[:,:14]
resul=DataFrame(inv_y3)
resul.to_csv('real_test.csv')
prono=DataFrame(inv_yhat3)
prono.to_csv('pronostico.csv')
# Out:
# (34, 14) (34, 20)

# %%
R=np.array(np.linspace(0,14,14))
RMSE=np.array(np.linspace(0,14,14))
from sklearn.metrics import mean_squared_error
from scipy.stats.stats import pearsonr

# calculate RMSE

for i in range(1,15):
    a=i
    r=pearsonr(inv_y3[:,a-1:a], inv_yhat3[:,a-1:a])
    rmse= np.sqrt(mean_squared_error(inv_y3[:,a-1:a], inv_yhat3[:,a-1:a]))
    R[i-1]=r[0]
    RMSE[i-1]=rmse
    
encabezadoR=['Pesq', 'R','RMSE']
tablaR=pd.DataFrame(columns=encabezadoR)
tablaR.Pesq=labelp
tablaR.R=R
tablaR.RMSE=RMSE
tablaR.to_csv('tablaR.csv') 
print(chr(27)+"[1m"+"Tabla 4. Resultados del rendimiento del modelo") 
print(chr(27)+"[0m"+tabulate(tablaR,showindex=False,headers=encabezadoR,tablefmt='fancy_grid'))
# Out:
# Tabla 4. Resultados del rendimiento del modelo
# ╒══════════════════╤════════════╤════════════════╕
# │ Pesq             │          R │           RMSE │
# ╞══════════════════╪════════════╪════════════════╡
# │ ABULON           │   0.075732 │   1914.19      │
# ├──────────────────┼────────────┼────────────────┤
# │ ALGAS            │ nan        │      6.84068   │
# ├──────────────────┼────────────┼────────────────┤
# │ ALMEJAS          │   0.196523 │  17448.1       │
# ├──────────────────┼────────────┼────────────────┤
# │ CALLO DE HACHA   │  -0.111071 │   6945.01      │
# ├──────────────────┼────────────┼────────────────┤
# │ CAMARON          │   0.318632 │   3050.91      │
# ├──────────────────┼────────────┼────────────────┤
# │ CANGREJO         │ nan        │      0.0067568 │
# ├──────────────────┼────────────┼────────────────┤
# │ CARACOL          │   0.267151 │  31490         │
# ├──────────────────┼────────────┼────────────────┤
# ...

# %%
pyplot.figure(figsize=(25,20))

pyplot.subplot(8,4,1)
pyplot.plot(inv_y3[:,0:1], label='y')
pyplot.plot(inv_yhat3[:,0:1], label='yhat')
pyplot.ylabel('Kg')
pyplot.xlabel('meses')
pyplot.title('ABULON ')
pyplot.grid(True)
pyplot.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

pyplot.subplot(8,4,5)
pyplot.plot(inv_y3[:,0:1],inv_yhat3[:,0:1],'bo')
pyplot.ylabel('y')
pyplot.xlabel('yhat')
pyplot.grid(True)

pyplot.subplot(8,4,2)
pyplot.plot(inv_y3[:,1:2], label='y')
pyplot.plot(inv_yhat3[:,1:2], label='yhat')
pyplot.ylabel('Kg')
pyplot.xlabel('meses')
pyplot.title('ALGAS')
pyplot.grid(True)
pyplot.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

pyplot.subplot(8,4,6)
pyplot.plot(inv_y3[:,1:2],inv_yhat3[:,1:2],'bo')
pyplot.ylabel('y')
pyplot.xlabel('yhat')
pyplot.grid(True)

pyplot.subplot(8,4,3)
pyplot.plot(inv_y3[:,2:3], label='y')
pyplot.plot(inv_yhat3[:,2:3], label='yhat')
pyplot.ylabel('Kg')
pyplot.xlabel('meses')
pyplot.title('ALMEJAS')
pyplot.grid(True)
pyplot.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

pyplot.subplot(8,4,7)
pyplot.plot(inv_y3[:,2:3],inv_yhat3[:,2:3],'bo')
pyplot.ylabel('y')
pyplot.xlabel('yhat')
pyplot.grid(True)

pyplot.subplot(8,4,4)
pyplot.plot(inv_y3[:,3:4], label='y')
pyplot.plot(inv_yhat3[:,3:4], label='yhat')
pyplot.ylabel('Kg')
pyplot.xlabel('meses')
pyplot.title('CALLO')
pyplot.grid(True)
pyplot.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)


pyplot.subplot(8,4,8)
pyplot.plot(inv_y3[:,3:4],inv_yhat3[:,3:4],'bo')
pyplot.ylabel('y')
pyplot.xlabel('yhat')
pyplot.grid(True)

pyplot.subplot(8,4,9)
pyplot.plot(inv_y3[:,4:5], label='y')
pyplot.plot(inv_yhat3[:,4:5], label='yhat')
pyplot.ylabel('Kg')
pyplot.xlabel('meses')
pyplot.title('CAMARON')
pyplot.grid(True)
pyplot.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

pyplot.subplot(8,4,13)
pyplot.plot(inv_y3[:,4:5],inv_yhat3[:,4:5],'bo')
pyplot.ylabel('y')
pyplot.xlabel('yhat')
pyplot.grid(True)


pyplot.subplot(8,4,10)
pyplot.plot(inv_y3[:,5:6], label='y')
pyplot.plot(inv_yhat3[:,5:6], label='yhat')
pyplot.ylabel('Kg')
pyplot.xlabel('meses')
pyplot.title('CANGREJO')
pyplot.grid(True)
pyplot.legend()
pyplot.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

pyplot.subplot(8,4,14)
pyplot.plot(inv_y3[:,5:6],inv_yhat3[:,5:6],'bo')
pyplot.ylabel('y')
pyplot.xlabel('yhat')
pyplot.grid(True)
pyplot.savefig('simulacion1.png')

pyplot.subplot(8,4,11)
pyplot.plot(inv_y3[:,6:7], label='y')
pyplot.plot(inv_yhat3[:,6:7], label='yhat')
pyplot.ylabel('Kg')
pyplot.xlabel('meses')
pyplot.title('CARACOL')
pyplot.grid(True)
pyplot.legend()

pyplot.subplot(8,4,15)
pyplot.plot(inv_y3[:,6:7],inv_yhat3[:,6:7],'bo')
pyplot.ylabel('y')
pyplot.xlabel('yhat')
pyplot.grid(True)

pyplot.subplot(8,4,12)
pyplot.plot(inv_y3[:,7:8], label='y')
pyplot.plot(inv_yhat3[:,7:8], label='yhat')
pyplot.ylabel('Kg')
pyplot.xlabel('meses')
pyplot.title('DEPORTIVAS')
pyplot.grid(True)
pyplot.legend()

pyplot.subplot(8,4,16)
pyplot.plot(inv_y3[:,7:8],inv_yhat3[:,7:8],'bo')
pyplot.ylabel('y')
pyplot.xlabel('yhat')
pyplot.grid(True)

pyplot.subplot(8,4,17)
pyplot.plot(inv_y3[:,8:9], label='y')
pyplot.plot(inv_yhat3[:,8:9], label='yhat')
pyplot.ylabel('Kg')
pyplot.xlabel('meses')
pyplot.title('ERIZO')
pyplot.grid(True)
pyplot.legend()

pyplot.subplot(8,4,21)
pyplot.plot(inv_y3[:,8:9],inv_yhat3[:,8:9],'bo')
pyplot.ylabel('y')
pyplot.xlabel('yhat')
pyplot.grid(True)


pyplot.subplot(8,4,18)
pyplot.plot(inv_y3[:,9:10], label='y')
pyplot.plot(inv_yhat3[:,9:10], label='yhat')
pyplot.ylabel('Kg')
pyplot.xlabel('meses')
pyplot.title('ESCAMA')
pyplot.grid(True)
pyplot.legend()

pyplot.subplot(8,4,22)
pyplot.plot(inv_y3[:,9:10],inv_yhat3[:,9:10],'bo')
pyplot.ylabel('y')
pyplot.xlabel('yhat')
pyplot.grid(True)

pyplot.subplot(8,4,19)
pyplot.plot(inv_y3[:,10:11], label='y')
pyplot.plot(inv_yhat3[:,10:11], label='yhat')
pyplot.ylabel('Kg')
pyplot.xlabel('meses')
pyplot.title('JAIBA')
pyplot.grid(True)
pyplot.legend()

pyplot.subplot(8,4,23)
pyplot.plot(inv_y3[:,10:11],inv_yhat3[:,10:11],'bo')
pyplot.ylabel('y')
pyplot.xlabel('yhat')
pyplot.grid(True)


pyplot.subplot(8,4,20)
pyplot.plot(inv_y3[:,11:12], label='y')
pyplot.plot(inv_yhat3[:,11:12], label='yhat')
pyplot.ylabel('Kg')
pyplot.xlabel('meses')
pyplot.title('JAIBA')
pyplot.grid(True)
pyplot.legend()

pyplot.subplot(8,4,24)
pyplot.plot(inv_y3[:,11:12],inv_yhat3[:,11:12],'bo')
pyplot.ylabel('y')
pyplot.xlabel('yhat')
pyplot.grid(True)


pyplot.subplot(8,4,25)
pyplot.plot(inv_y3[:,12:13], label='y')
pyplot.plot(inv_yhat3[:,12:13], label='yhat')
pyplot.ylabel('Kg')
pyplot.xlabel('meses')
pyplot.title('OTROS')
pyplot.grid(True)
pyplot.legend()

pyplot.subplot(8,4,29)
pyplot.plot(inv_y3[:,12:13],inv_yhat3[:,12:13],'bo')
pyplot.ylabel('y')
pyplot.xlabel('yhat')
pyplot.grid(True)


pyplot.subplot(8,4,26)
pyplot.plot(inv_y3[:,13:14], label='y')
pyplot.plot(inv_yhat3[:,13:14], label='yhat')
pyplot.ylabel('Kg')
pyplot.xlabel('meses')
pyplot.title('TIBURONES')
pyplot.grid(True)
pyplot.legend()

pyplot.subplot(8,4,30)
pyplot.plot(inv_y3[:,13:14],inv_yhat3[:,13:14],'bo')
pyplot.ylabel('y')
pyplot.xlabel('yhat')
pyplot.grid(True)

pyplot.subplot(8,4,27)
pyplot.plot(inv_y3[:,14:15], label='y')
pyplot.plot(inv_yhat3[:,14:15], label='yhat')
pyplot.ylabel('Kg')
pyplot.xlabel('meses')
pyplot.title('TUNIDOS')
pyplot.grid(True)
pyplot.legend()

pyplot.subplot(8,4,31)
pyplot.plot(inv_y3[:,14:15],inv_yhat3[:,14:15],'bo')
pyplot.ylabel('y')
pyplot.xlabel('yhat')
pyplot.grid(True)


pyplot.subplots_adjust(top=0.82, bottom=0.10, left=0.15, right=1, hspace=0.5,
                    wspace=1.0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-19-a003205183a5> in <module>()
#     220
#     221 pyplot.subplot(8,4,27)
# --> 222 pyplot.plot(inv_y3[:,14:15], label='y')
#     223 pyplot.plot(inv_yhat3[:,14:15], label='yhat')
#     224 pyplot.ylabel('Kg')
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3259                       mplDeprecation)
#    3260     try:
# -> 3261         ret = ax.plot(*args, **kwargs)
#    3262     finally:
#    3263         ax._hold = washold
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
# ...
